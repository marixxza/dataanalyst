# %%
import numpy as np
import pandas as pd
import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from __future__ import division
import matplotlib.pyplot as plt

# %%
TWITTER_CONSUMER_KEY = 'lErR8HLhxBMSPIDOygB8utQrw'
TWITTER_CONSUMER_SECRET = '3muWu9tjrIZCj2xW0C9XOnTTqXZJLCh7zaJMET080JIlOQP51c'
TWITTER_OAUTH_TOKEN = '249379058-bhzc4sMe8EwqppoXLLmgXZK9DvxeBJSlR6HafqeV'
TWITTER_OAUTH_SECRET = '4Dw9RKAyIAXCA61dFZuNuWcFpixAX7CJicnBU5cgtdh6P'

# %%
auth= tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
auth.set_access_token(TWITTER_OAUTH_TOKEN, TWITTER_OAUTH_SECRET)

# %%
api= tweepy.API(auth)
public_tweets=api.home_timeline()
for tweet in public_tweets:
    print tweet.text
# Out:
# Auditoría de SFP señala que mala planeación en el Paso Exprés ocasionó retrasos y deficiencias en la obra https://t.co/DMANKzC6Od
# RT @AleGomezMx: Ni tingi nidi qi iclirir piqi yi ni firmi isis cintritis https://t.co/cQORhCnLdZ
# Up to six shot at high school near Spokane, Washington https://t.co/u1T0Ngg1la
# Cobre se desploma a mínimo de tres semanas
# https://t.co/IaQLbvxuXJ
# 12 Things You Might Not Know About #Platinum’s Uses
# https://t.co/67nee70mAW #preciousmetals #industrial #metals… https://t.co/cXxWirMLlf
# Netanyahu alerta a Macri sobre el terrorismo iraní https://t.co/3XePVeHNsf https://t.co/GFEtINMwcr
# Peña Nieto encabeza clausura y apertura de Cursos de los ... :...https://t.co/XTra9KZ5E2
# A pie y cargando bolsa de 10 kg, mujer de 81 años acude al zócalo a donar para damnificados https://t.co/XTZWo2VMXR https://t.co/VzBRtI57sI
# Peña Nieto conmemora gesta heroica de Niños Héroes :...https://t.co/Olyo1o2fMY
# Rápido, Locchio dile a Don Álvaro que saque el fondo de recompra, ya ves que te hace un chingo de caso y jajajaja😂
# Ataque a bar deja 5 muertos y un herido en Irapuato, Guanajuato
# https://t.co/wA6qmBlIdP https://t.co/O7yvs23qqV
# RT @lajornadaonline: #MonerosLaJornada Emergencia en Chiapas, cartón de @ahelguera https://t.co/skIPYrf2mO https://t.co/iM9phPXBGe
# Furgoneta enciende alarma terrorista en Barcelona https://t.co/0AfFpWxBW5 https://t.co/O6TpWGVOh5
# RT @marketminute: $TLT got within 1.00 from target (125.50) if short. Definitely time to go to a no loss stop if bought $TBTs.
# .@EricaCarmel @helene_dina @laxmiw: What will section mate @changds, fellow alumni be up to this year? See at https://t.co/H2qEsUmBZv :)
# Ahora Inclusión para el México Digital. @elenaestavillo @LabardiniA @ONUMujeresMX #JulietteBonaffe #YolandaMartinez… https://t.co/egSoKuFQHs
# RT @ncerecedob_: @myclown4u @wikituitter @msylvestre66 @Trolmalpagado @Changonazo @YO_____MERO @luisfevidal @ajsmcdmx @Pitu_fox @yaromir118…
# Sedena concluye campaña de canje de armas en la Sierra - Noticias de Querétaro https://t.co/SX5fqCDsp8
# Abandonan caja de tráiler - Noticias de Querétaro https://t.co/zNYVBGpx3H
# You're more likely to achieve the American dream if you live in #Denmark https://t.co/gZX5fCWRv4 #inequality https://t.co/aZ2LDmMM8r

# %%
def toDataFrame(tweets):
    dataset=pd.DataFrame()
    
    dataset['userID']=[tweet.user.id for tweet in tweets]
    dataset['id']=[tweet.id for tweet in tweets]
    dataset['userName']=[tweet.user.name for tweet in tweets]
    dataset['tweetText']=[tweet.text for tweet in tweets]
    dataset['tweetCreated']=[tweet.created_at for tweet in tweets]
    dataset['userLocation']=[tweet.user.location for tweet in tweets]
    
    dataset['url']=[tweet.source_url for tweet in tweets]
    dataset['Geo']=[tweet.geo for tweet in tweets]
    dataset['Usuario']=[tweet.user for tweet in tweets]
    dataset['Numero/Favs']=[tweet.favorite_count for tweet in tweets]
    
    return dataset

# %%
tweet_frame= toDataFrame(public_tweets)

# %%
tweet_frame
# Out:
#         userID                  id              userName  \
# 0     27708897  908043732259414018            REFORMACOM
# 1     70156689  908043728786509834            Oscar Coss
# 2      1652541  908043720632754178      Reuters Top News
# 3     89589379  908043700118228995    Moisés Cortés 🇲🇽
# 4   3617663605  908043696138063874       Brian D Colwell
# 5   4198346793  908043649639960577           EP | Social
# 6    245990501  908043629381513217       Noticias Mexico
# 7    109651819  908043617499074560                FOROtv
# 8    245990501  908043606736465921       Noticias Mexico
# 9   2786884394  908043527845801984    Experto Bursátil ☯
# 10   109651819  908043408106815490                FOROtv
# 11    36127907  908043390599565312         trino camacho
# 12  4198346793  908043330197639168           EP | Social
# 13  1092348054  908043286866223108                  Yale
# 14    24189159  908043282856505344            HBS Alumni
# 15    20292293  908043233019797505        Claudia Calvin
# 16   183562840  908043183468302339          Rafael Norma
# 17   396049840  908043180796514304    Noticias Querétaro
# 18   396049840  908043177726238722    Noticias Querétaro
# 19     5120691  908043144016560128  World Economic Forum
#
#                                             tweetText        tweetCreated  \
# 0   Auditoría de SFP señala que mala planeación en... 2017-09-13 19:04:31
# 1   RT @AleGomezMx: Ni tingi nidi qi iclirir piqi ... 2017-09-13 19:04:30
# 2   Up to six shot at high school near Spokane, Wa... 2017-09-13 19:04:28
# 3   Cobre se desploma a mínimo de tres semanas \nh... 2017-09-13 19:04:23
# 4   12 Things You Might Not Know About #Platinum’s... 2017-09-13 19:04:22
# 5   Netanyahu alerta a Macri sobre el terrorismo i... 2017-09-13 19:04:11
# 6   Peña Nieto encabeza clausura y apertura de Cur... 2017-09-13 19:04:06
# 7   A pie y cargando bolsa de 10 kg, mujer de 81 a... 2017-09-13 19:04:03
# 8   Peña Nieto conmemora gesta heroica de Niños Hé... 2017-09-13 19:04:01
# 9   Rápido, Locchio dile a Don Álvaro que saque el... 2017-09-13 19:03:42
# 10  Ataque a bar deja 5 muertos y un herido en Ira... 2017-09-13 19:03:13
# 11  RT @lajornadaonline: #MonerosLaJornada Emergen... 2017-09-13 19:03:09
# 12  Furgoneta enciende alarma terrorista en Barcel... 2017-09-13 19:02:55
# 13  RT @marketminute: $TLT got within 1.00 from ta... 2017-09-13 19:02:44
# 14  .@EricaCarmel @helene_dina @laxmiw: What will ... 2017-09-13 19:02:43
# 15  Ahora Inclusión para el México Digital. @elena... 2017-09-13 19:02:32
# 16  RT @ncerecedob_: @myclown4u @wikituitter @msyl... 2017-09-13 19:02:20
# 17  Sedena concluye campaña de canje de armas en l... 2017-09-13 19:02:19
# 18  Abandonan caja de tráiler - Noticias de Querét... 2017-09-13 19:02:18
# 19  You're more likely to achieve the American dre... 2017-09-13 19:02:10
#
#                  userLocation                                  url   Geo  \
# 0                      México       http://Sitio.com/callback.aspx  None
# 1                 México D.F.   http://twitter.com/download/iphone  None
# 2            Around the world            http://www.socialflow.com  None
# 3            Ciudad de México  http://twitter.com/download/android  None
# 4               San Diego, CA        https://www.socialjukebox.com  None
# 5                       Mundo          http://www.ajaymatharu.com/  None
# 6                                            http://twitraf.ven.bz  None
# 7                   México DF             http://www.hootsuite.com  None
# 8                                            http://twitraf.ven.bz  None
# 9                        CDMX                   http://twitter.com  None
# 10                  México DF             http://www.hootsuite.com  None
# 11                     mexico   http://twitter.com/download/iphone  None
# 12                      Mundo          http://www.ajaymatharu.com/  None
# 13                                      https://mobile.twitter.com  None
# 14                 Boston, MA                   http://twitter.com  None
# 15        México, aquí y allá  http://twitter.com/download/android  None
# 16  EN EL DEFECADO DEFECTUOSO                   http://twitter.com  None
# 17                  Querétaro                    https://ifttt.com  None
# 18                  Querétaro                    https://ifttt.com  None
# 19        Geneva, Switzerland                 http://bufferapp.com  None
#
#                                               Usuario  Numero/Favs
# 0   User(follow_request_sent=False, has_extended_p...            0
# 1   User(follow_request_sent=False, has_extended_p...            0
# 2   User(follow_request_sent=False, has_extended_p...            0
# 3   User(follow_request_sent=False, has_extended_p...            0
# 4   User(follow_request_sent=False, has_extended_p...            0
# 5   User(follow_request_sent=False, has_extended_p...            0
# 6   User(follow_request_sent=False, has_extended_p...            0
# 7   User(follow_request_sent=False, has_extended_p...            0
# 8   User(follow_request_sent=False, has_extended_p...            0
# 9   User(follow_request_sent=False, has_extended_p...            0
# 10  User(follow_request_sent=False, has_extended_p...            1
# 11  User(follow_request_sent=False, has_extended_p...            0
# 12  User(follow_request_sent=False, has_extended_p...            0
# 13  User(follow_request_sent=False, has_extended_p...            0
# 14  User(follow_request_sent=False, has_extended_p...            0
# 15  User(follow_request_sent=False, has_extended_p...            0
# 16  User(follow_request_sent=False, has_extended_p...            0
# 17  User(follow_request_sent=False, has_extended_p...            0
# 18  User(follow_request_sent=False, has_extended_p...            0
# 19  User(follow_request_sent=False, has_extended_p...            6

# %%
tweetsPorHora= tweet_frame[['userID','tweetCreated']]
tweetsPorHora.loc[:,('tweetCreated')]=tweetsPorHora['tweetCreated'].map(
    lambda x: x.strftime('%H:%M:%S') if x else '')
#tweetsPorHora
tweetsPorMinuto=tweet_frame[['userID','tweetCreated']]
tweetsPorMinuto.loc[:,('tweetCreated')]=tweetsPorMinuto['tweetCreated'].map(
    lambda x: x.strftime('%M') if x else '')
tweetsPorMinuto
# Out:
#         userID tweetCreated
# 0     27708897           04
# 1     70156689           04
# 2      1652541           04
# 3     89589379           04
# 4   3617663605           04
# 5   4198346793           04
# 6    245990501           04
# 7    109651819           04
# 8    245990501           04
# 9   2786884394           03
# 10   109651819           03
# 11    36127907           03
# 12  4198346793           02
# 13  1092348054           02
# 14    24189159           02
# 15    20292293           02
# 16   183562840           02
# 17   396049840           02
# 18   396049840           02
# 19     5120691           02

# %%
TpMDroped=tweetsPorMinuto.groupby('tweetCreated').count()
TpMDroped
# Out:
#               userID
# tweetCreated
# 02                 8
# 03                 3
# 04                 9

# %%
# %matplotlib inline
TpMDroped.plot(legend=True)
plt.legend(['Tweets Por Minuto'])
plt.xlabel('Minuto')
plt.ylabel('No. de Tweets')
ax=plt.axes()
ax.set_facecolor('gold')

# %%
tweetsPorFecha=tweet_frame[['tweetCreated','userID']]
#tweetsPorFecha['tweetCreated']=tweetsPorFecha['tweetCreated'].map(lambda x: x.strftime('%Y/%m/%d') if x else '')
tweetsPorFecha.loc[:,('tweetCreated')]=tweetsPorFecha['tweetCreated'].map(lambda x: x.strftime('%Y/%m/%d') if x else '')
tweetsPorFecha
# Out:
#    tweetCreated      userID
# 0    2017/09/13    27708897
# 1    2017/09/13    70156689
# 2    2017/09/13     1652541
# 3    2017/09/13    89589379
# 4    2017/09/13  3617663605
# 5    2017/09/13  4198346793
# 6    2017/09/13   245990501
# 7    2017/09/13   109651819
# 8    2017/09/13   245990501
# 9    2017/09/13  2786884394
# 10   2017/09/13   109651819
# 11   2017/09/13    36127907
# 12   2017/09/13  4198346793
# 13   2017/09/13  1092348054
# 14   2017/09/13    24189159
# 15   2017/09/13    20292293
# 16   2017/09/13   183562840
# 17   2017/09/13   396049840
# 18   2017/09/13   396049840
# 19   2017/09/13     5120691

# %%
TpFDroped=tweetsPorFecha.groupby('tweetCreated').count()
TpFDroped
# Out:
#               userID
# tweetCreated
# 2017/09/13        20

# %%
# %matplotlib inline
TpFDroped.plot(kind='bar', legend=True)
#plt.legend(['Tweets creados por día'])
#plt.xlabel('Número de Tweets')
#plt.ylabel('No. de Tweets')

#ax.yaxis.set_ticks_position('none')

# %%
tweetsPorLocacion= tweet_frame[['userLocation','userID']].groupby('userLocation').count()
tweetsPorLocacion
# Out:
#                               userID
# userLocation
#                                    1
# Ciudad de México                   2
# Cuenca, Ecuador                    1
# Madrid                             1
# Miami - Londres - Madrid           1
# Mundo                              4
# New York and the World             2
# Querétaro, Querétaro Arteaga       2
# Times Square, New York             1
# Washington, DC                     2
# Where you are                      1

# %%
# %matplotlib inline
tweetsPorLocacion.plot(kind='bar', legend=True)

# %%
api= tweepy.API(auth)
public_tweets=api.home_timeline()
for tweet in public_tweets:
    print tweet.text
# %time
# Out:
# Una vez que te olvides lo que vales, te olvidarás lo que te mereces
# Graficos de 1H NY actualizados en nuestro sitio.Prueba EWF GRATIS&gt;https://t.co/hBwHydb3Wx #elliottwave #ondaselliott
# Las medidas extremas para el nuevo año escolar https://t.co/t0yl9Tcm2Z https://t.co/zThdbR5oeF
# A este grupito se le acabó el negocio de “narcobrownie” https://t.co/iKUV9Zsusc https://t.co/WJv7gQIxy3
# Anuncia Angélica Rivera donación de 100 viviendas para Chiapas y Oaxaca
# https://t.co/F0E1Thuip5 https://t.co/c2fnnGoGOk
# Amazing conversation with Schwarzman Scholars at Tsinghua University on the future of jobs, economy &amp; gender parity… https://t.co/gCWRu2Urwi
# El hermano de Janet Jackson afirma que el matrimonio de la cantante escondía una "relación abusiva" https://t.co/dx76Oe8O73
# Appeals court says Uber cannot move Waymo court fight to arbitration https://t.co/97EyVhlmZM
# We test-drove 3 popular SUVs to find out which car blends the very finest in convenience, comfort, and performance… https://t.co/1xLgVG3RNk
# ¡Un poema! La cara de los ministros mientras Maduro echa cuento https://t.co/sDHdS2C5La https://t.co/XGEqF3Hg1T
# ¡Salada! Conoce los detalles de la deportación de La Divaza (Video) https://t.co/nvAMU34wYA https://t.co/EhblK0kUuO
# New ep. of @FootyForTwo: How Ernesto Valverde reinvigorated @FCBarcelona. Plus, the opening @ChampionsLeague games. https://t.co/Zl5WDIzfQG
# Midweek #FIASmartbrief snippet: Basel Committee says banks are meeting capital requirements https://t.co/0GvN9PmBUy
# .@Nasdaq has been named to the 2017 @RobecoSAM #DJSI again for our continuing commitment to #sustainability… https://t.co/Fk4pUswPvB
# Siguen apareciendo los socavones en la CDMX https://t.co/dWaHsSkncz
# Construction companies make billions from ever costlier disasters https://t.co/Q3Eb0heMFu https://t.co/GFLjEnY2pB
# Arca Continental busca recabar 7 mil mdp con venta de dos bonos - https://t.co/ZHDNxNc9Rs
# Ahi te hablan @gruizesp ¿Cuando vas a renunciar? ¿Cuando vas a rendir cuentas? ¿Cuando habrá sanción a los responsa… https://t.co/kpsnA5vbVG
# CPU times: user 4 µs, sys: 4 µs, total: 8 µs
# Wall time: 9.06 µs
